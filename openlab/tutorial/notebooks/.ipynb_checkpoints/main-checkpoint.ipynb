# %% [markdown]
# ## Introduction
# This is a hands-on guide to ...
# ### [How to use the openlab web application](https://live.openlab.app/)

# %% [markdown]
# ## Network

# %%
print("some code here")
# Out:
# some code here

# %% [markdown]
# ## Configuration

# %%
print("Some information about the configuration")
# Out:
# Some information about the configuration

# %% [markdown]
# ## Simulation

# %%
print("Kick a simulation")
# Out:
# Kick a simulation

# %% [markdown]
# ## Sending set points

# %%
print("How to manage set points")
# Out:
# How to manage set points

# %% [markdown]
# ## Getting simulation results

# %%
print("Printing and plotting results")
# Out:
# Printing and plotting results

# %% [markdown]
# ## Example PID controller

# %%
import openlab
print("Good controller here :-) ")
# Out:
# Good controller here :-)
